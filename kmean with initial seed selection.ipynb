# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# # Dataset

# %%
data=pd.read_csv('/home/root123/Documents/trainreg.csv')

# %%
data.shape
# Out:
# (299, 5)

# %%
data.head(10)
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43
# 5  13.97  39.16  1016.05  84.60  470.96
# 6  22.10  71.29  1008.20  75.38  442.35
# 7  14.47  41.76  1021.98  78.41  464.00
# 8  31.25  69.51  1010.25  36.83  428.77
# 9   6.77  38.18  1017.80  81.13  484.31

# %%
data=data.values

# %% [markdown]
# # Initial seed selection

# %%
def seed_selection(n):
    k=[0]*n
    seed=np.random.randint(data.shape[0], size=1)
    for i in range(n):
        if i==0:
            k[0]=math.floor(seed)
        elif (i==1):
            k[1]=math.floor(k[0]/2)
        else:
            k[i]=math.floor(sum(k)/len(k))
    return(k)

# %%
k=seed_selection(6)
k
# Out:
# [275, 137, 68, 80, 93, 108]

# %%
dist_mat = np.zeros((len(k),299))

# %% [markdown]
# # Distance matrix

# %%
def eclid_distance(centroid):
    for i in range(len(centroid)):
        for j in range(data.shape[0]):
              dist_mat[i][j] =np.sqrt(np.sum(np.square(centroid[i]-data[j:j+1,])))       
    return(dist_mat)

# %% [markdown]
# # kmean

# %%
def kmean(k):
    centroid=[]
    for i in range(len(k)):
        centroid.append(data[k[i]])
    dist_mat=eclid_distance(centroid)
    for i in range(10):
        x = [[] for _ in range(len(k))]
        for i in range(data.shape[0]):
            for j in range(len(k)):
                if (dist_mat[:,i])[j]==dist_mat[:,i].min():
                    x[j].append(data[i])
        for i in range(len(k)):
            x[i]=np.array(x[i])
            centroid[i]=x[i].mean(axis=0)
    return(x)

# %%
kmean(k)
# Out:
# [array([[  22.1 ,   71.29, 1008.2 ,   75.38,  442.35],
#         [  22.56,   70.79, 1005.85,   93.09,  435.14],
#         [  21.48,   66.91, 1008.58,   84.49,  447.42],
#         [  21.47,   70.32, 1011.72,   88.36,  440.  ],
#         [  25.82,   72.39, 1003.4 ,   86.33,  432.98],
#         [  23.7 ,   69.23, 1011.73,   73.18,  437.15],
#         [  29.11,   74.9 , 1003.31,   74.01,  432.43],
#         [  23.73,   61.02, 1009.71,   78.7 ,  442.22],
#         [  26.87,   74.99, 1002.48,   71.91,  437.78],
#         [  30.61,   77.17, 1009.49,   73.19,  430.46],
#         [  23.4 ,   72.99, 1009.48,   88.82,  438.51],
#         [  30.31,   77.24, 1008.02,   67.84,  435.28],
#         [  25.34,   71.06, 1007.74,   92.52,  434.86],
#         [  22.1 ,   74.87, 1009.4 ,   85.78,  442.83],
#         [  23.25,   70.32, 1009.28,   86.52,  437.96],
#         [  23.39,   71.25, 1005.22,   93.7 ,  435.68],
#         [  25.93,   69.34, 1008.91,   79.43,  434.08],
# ...
